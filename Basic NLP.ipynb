# %%
import pandas as pd
import nltk
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\ushas\Downloads\SMS_train.tsv",sep='\t')

# %%
dataset.head(45)
# Out:
#                                          Message_body     Label
# 0                          Rofl. Its true to its name  Non-Spam
# 1   The guy did some bitching but I acted like i'd...  Non-Spam
# 2   Pity, * was in mood for that. So...any other s...  Non-Spam
# 3                Will � b going to esplanade fr home?  Non-Spam
# 4   This is the 2nd time we have tried 2 contact u...      Spam
# 5   REMINDER FROM O2: To get 2.50 pounds free call...      Spam
# 6                                        Huh y lei...  Non-Spam
# 7   Why don't you wait 'til at least wednesday to ...  Non-Spam
# 8                                 Ard 6 like dat lor.  Non-Spam
# 9   Ok lor... Sony ericsson salesman... I ask shuh...  Non-Spam
# 10  Get me out of this dump heap. My mom decided t...  Non-Spam
# 11                  Anything lor. Juz both of us lor.  Non-Spam
# 12  if you aren't here in the next  &lt;#&gt;  hou...  Non-Spam
# 13                             Sorry, I'll call later  Non-Spam
# 14  No. I meant the calculation is the same. That ...  Non-Spam
# 15  Yes i have. So that's why u texted. Pshew...mi...  Non-Spam
# 16  Yeh. Indians was nice. Tho it did kane me off ...  Non-Spam
# 17  Well keep in mind I've only got enough gas for...  Non-Spam
# 18                        Hahaha..use your brain dear  Non-Spam
# 19  Have a safe trip to Nigeria. Wish you happines...  Non-Spam
# 20  Wen did you get so spiritual and deep. That's ...  Non-Spam
# 21        Cool, what time you think you can get here?  Non-Spam
# 22  You know, wot people wear. T shirts, jumpers, ...  Non-Spam
# 23                 No, I was trying it all weekend ;V  Non-Spam
# 24         Ic. There are a lotta childporn cars then.  Non-Spam
# 25      Hi its in durban are you still on this number  Non-Spam
# 26  I'm taking derek &amp; taylor to walmart, if I...  Non-Spam
# 27             U still havent got urself a jacket ah?  Non-Spam
# 28           Armand says get your ass over to epsilon  Non-Spam
# 29                              Yeah it's jus rite...  Non-Spam
# 30  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...      Spam
# 31                         Just sleeping..and surfing  Non-Spam
# 32  I can't believe how attached I am to seeing yo...  Non-Spam
# 33  Want explicit SEX in 30 secs? Ring 02073162414...      Spam
# 34  Aiyah ok wat as long as got improve can alread...  Non-Spam
# 35  I know you are thinkin malaria. But relax, chi...  Non-Spam
# 36                       Ok which your another number  Non-Spam
# 37  Hey chief, can you give me a bell when you get...  Non-Spam
# 38           happened here while you were adventuring  Non-Spam
# 39  Compliments to you. Was away from the system. ...  Non-Spam
# 40  I think that tantrum's finished so yeah I'll b...  Non-Spam
# 41                          What about this one then.  Non-Spam
# 42  Its just the effect of irritation. Just ignore it  Non-Spam
# 43  Total disappointment, when I texted you was th...  Non-Spam
# 44  PRIVATE! Your 2003 Account Statement for shows...      Spam

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
corpus=[]
for i in range(0,957):
    review=re.sub('[^a-zA-z]',' ',dataset['Message_body'][i])
    review=review.lower()
    review=review.split()
    ps=PorterStemmer()
    review=[ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review=' '.join(review)
    corpus.append(review)
# print(corpus)
# print(dataset['Review'][0])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=1500)
X=cv.fit_transform(corpus).toarray()
y=dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# Training the Naive Bayes model on the Training set
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

y_pred=classifier.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc=accuracy_score(y_test, y_pred)
print(acc)
# Out:
# [[206   0]
#  [ 20  14]]
# 0.9166666666666666
